# %%
# !pip install timm
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 180 kB 67.1 MB/s
# ...
#      |████████████████████████████████| 142 kB 54.3 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.4 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=be56082da7fdc95226823bc6763af126aaf610cd7d7358cfad10fe6373c9a903
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=f16caa6a8d7ddc52cdb460ada836100a405e122692e57767ea953d3514905875
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...

# %%
# !git clone https://github.com/rwightman/pytorch-image-models.git
# Out:
# Cloning into 'pytorch-image-models'...
# remote: Enumerating objects: 9281, done.
# remote: Counting objects: 100% (327/327), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 9281 (delta 193), reused 222 (delta 132), pack-reused 8954
# Receiving objects: 100% (9281/9281), 18.45 MiB | 32.92 MiB/s, done.
# Resolving deltas: 100% (6821/6821), done.

# %% [markdown]
# # get data

# %%
from google.colab import drive
drive.mount('/content/drive2')

# !cp '/content/drive2/MyDrive/Fast/Semester7/fyp/data.zip' data.zip
# !unzip data.zip
# Out:
# Mounted at /content/drive2
# Archive:  data.zip
#    creating: normal_patches/
#   inflating: normal_patches/8705.png
#   inflating: normal_patches/6958.png
#   inflating: normal_patches/5786.png
#   inflating: normal_patches/3066.png
#   inflating: normal_patches/5517.png
#   inflating: normal_patches/13423.png
#   inflating: normal_patches/15005.png
#   inflating: normal_patches/27615.png
#   inflating: normal_patches/13356.png
#   inflating: normal_patches/19357.png
#   inflating: normal_patches/12436.png
#   inflating: normal_patches/566.png
#   inflating: normal_patches/21515.png
#   inflating: normal_patches/16532.png
#   inflating: normal_patches/12673.png
#   inflating: normal_patches/21011.png
#   inflating: normal_patches/13613.png
#   inflating: normal_patches/7030.png
#   inflating: normal_patches/19505.png
#   inflating: normal_patches/20479.png
#   inflating: normal_patches/4626.png
#   inflating: normal_patches/26422.png
#   inflating: normal_patches/27085.png
# ...

# %%
# !mkdir data
# !mv patches/ normal_patches/ data

# %% [markdown]
# # model

# %%
# %cd /content/pytorch-image-models
# !./distributed_train.sh 1 ../data --model resnet34 --lr 0.0005 --opt adam --pretrained \
    --sched tanh --lr-cycle-mul 2 --lr-cycle-limit 10 \
    --aa orignal \
    \#--cutmix 0.5 \
    --log-wandb
# Out:
# /content/pytorch-image-models
# /usr/local/lib/python3.7/dist-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# wandb: Currently logged in as: phelenon (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.9
# wandb: Syncing run bright-sponge-17
# wandb: ⭐️ View project at https://wandb.ai/phelenon/pytorch-image-models
# wandb: 🚀 View run at https://wandb.ai/phelenon/pytorch-image-models/runs/36rz8deb
# wandb: Run data is saved locally in /content/pytorch-image-models/wandb/run-20220125_005302-36rz8deb
# ...

# %%
# %cd /content/pytorch-image-models
# !./distributed_train.sh 1 ../data --model resnet34 --lr 0.0005 --opt adam --pretrained \
    --lr-cycle-mul 2 --lr-cycle-limit 10 \
    --aa original \
    --log-wandb
# Out:
# /content/pytorch-image-models
# /usr/local/lib/python3.7/dist-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# wandb: Currently logged in as: phelenon (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.9
# wandb: Syncing run fiery-dew-20
# wandb: ⭐️ View project at https://wandb.ai/phelenon/pytorch-image-models
# wandb: 🚀 View run at https://wandb.ai/phelenon/pytorch-image-models/runs/27u6j3aw
# wandb: Run data is saved locally in /content/pytorch-image-models/wandb/run-20220125_012809-27u6j3aw
# wandb: Run `wandb offline` to turn off syncing.
# ...

# %%
# %cd /content/pytorch-image-models
# !./distributed_train.sh 1 ../data --model resnet34 --lr 0.0005 --opt adam --pretrained \
    --lr-cycle-mul 2 --lr-cycle-limit 10 \
    --aa original \
    --cutmix 0.5 \
    --log-wandb
# Out:
# /content/pytorch-image-models
# /usr/local/lib/python3.7/dist-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# wandb: Currently logged in as: phelenon (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.9
# wandb: Syncing run smart-resonance-19
# wandb: ⭐️ View project at https://wandb.ai/phelenon/pytorch-image-models
# wandb: 🚀 View run at https://wandb.ai/phelenon/pytorch-image-models/runs/bsch0xjw
# wandb: Run data is saved locally in /content/pytorch-image-models/wandb/run-20220125_012403-bsch0xjw
# ...

# %%
# !rm -r /content/pytorch-image-models/output/train
